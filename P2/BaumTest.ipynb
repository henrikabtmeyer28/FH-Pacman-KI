# %% [markdown]
# # Praktikum 2 Aufgabenstellung:
# Wir arbeiten jetzt erstmal ohne den Server, um das grundlegende Prinzip dahinter zu verstehen. Daher wird hier nur mit dem String-Array gearbeitet und nicht mit dem eigentlich Numpy-Array.
# Überlegt euch was die Knoten-Klasse repräsentiert und kommentiert die untere Zeile ein.
#
# **Tipp:** Nutzt das Jupyter Notebook erstmal für die Experimente, um zu schauen was bei den einzelnen Operation passiert, bevor ihr die Funktionen in die Knoten-Klasse implementiert [Knoten.py](Knoten.py)

# %%
from Knoten import Knoten

# %%
level = [
    ["#", "#", "#", "#"],
    ["#", " ", "*", "#"],
    ["#", "*", "#", "#"],
    ["#", "#", "#", "#"]
]

# %%
pacman_pos_x = 1
pacman_pos_y = 1

# %%
if __name__ == "__main__":
    start = Knoten(level, pacman_pos_x, pacman_pos_y)
    knoten = [start]
    expanded = []
    while knoten and len(expanded) < 10:
        current = knoten.pop(0)
        position = (current.pos_x, current.pos_y)
        expanded.append(current)
        print(f"Knoten: {position}, Inhalt: {current.content}, Tiefe: {current.depth}")  # Ausgabe
        for child in current.expand():
            knoten.append(child)

    '''
    possibleSteps = start.tiefensuche()
    for step in possibleSteps:
        print(step.pos_x, step.pos_y)
    '''
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 9
#       7 position = (current.pos_x, current.pos_y)
#       8 expanded.append(current)
# ----> 9 print(f"Knoten: {position}, Inhalt: {current.content}, Tiefe: {current.depth}")  # Ausgabe
#      10 for child in current.expand():
#      11     knoten.append(child)
#
# AttributeError: 'Knoten' object has no attribute 'content'
